# %%
# %run Portfolio_2.ipynb
# Out:
# Current Year:  2023
# 56855
# 56855
# Age              5.0
# mileage       9529.0
# mpg             60.1
# engineSize       1.0
# Name: 83625, dtype: float64
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.701
# Model:                            OLS   Adj. R-squared:                  0.701
# Method:                 Least Squares   F-statistic:                 3.326e+04
# Date:                Thu, 14 Dec 2023   Prob (F-statistic):               0.00
# Time:                        15:42:23   Log-Likelihood:            -5.7206e+05
# No. Observations:               56855   AIC:                         1.144e+06
# Df Residuals:                   56850   BIC:                         1.144e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
cars_dummied
# Out:
#        price  Age  mileage   mpg  engineSize  transmission_Automatic  \
# 0      12500    6    15735  55.4         1.4                       0
# 1      16500    7    36203  64.2         2.0                       1
# 2      11000    7    29946  55.4         1.4                       0
# 3      16800    6    25952  67.3         2.0                       1
# 4      17300    4     1998  49.6         1.0                       0
# ...      ...  ...      ...   ...         ...                     ...
# 90570   5990   11    74000  58.9         2.0                       0
# 90571   1799   15    88102  46.3         1.2                       0
# 90572   1590   14    70000  42.0         1.4                       0
# 90573   1250   17    82704  46.3         1.2                       0
# 90574   2295   16    74000  46.3         1.2                       0
#
#        transmission_Manual  transmission_Other  transmission_Semi-Auto  \
# ...

# %%
from sklearn.linear_model import Lasso

# %%
algo_lasso = Lasso(alpha=0.4)

# %%
algo_lasso.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.4)

# %%
y_pred = algo_lasso.predict(X_test)

# %%
print("R2 score : %.2f" % r2_score(y_test, y_pred))
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# Out:
# R2 score : 0.73
# Mean squared error: 29859776.67

# %% [markdown]
# This implies that 73% of the variability of in target (Price) is explained by the model

# %%
y_test_100 = y_test[0:101]
y_pred_100 = y_pred[:101]
x_100      = np.arange(0, 101).tolist()

# %%
plt.plot(x_100, y_test_100, label = "Actual Sell Price") 
plt.plot(x_100, y_pred_100, label = "Predicted Sell Price") 
plt.legend() 
plt.show()
